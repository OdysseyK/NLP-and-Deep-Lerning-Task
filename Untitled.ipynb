# %%
# Papers

""" 
1. Don’t Classify, Translate

In this paper, researchers from the National University of Singapore and the Rakuten Institute of Technology propose and explain a novel machine translation approach to product categorization.
Their method converts a product’s description into a sequence of tokens, which represent a root-to-leaf path to the correct category.
Using this method, they are also able to propose meaningful new paths in the taxonomy.
"""
""" 
2. Multi-Label Product Categorization Using Multi-Modal Fusion Models

In this paper, researchers from New York University and U.S. Bank investigate multi-modal approaches to categorize products on Amazon. 
Their approach utilizes multiple classifiers trained on each type of input data from the product listings.
Using a dataset of 9.4 million Amazon products, they developed a tri-modal model for product classification based on product images, titles, and descriptions.
Their tri-modal late fusion model retains an F1 score of 88.2%. 
"""
""" 
3. Bag of Tricks for Efficient Text Classification

This paper explores a simple and efficient baseline for text classification.
Our experiments show that our fast text classifier fastText is often on par with deep learning classifiers in terms of accuracy, and many orders of magnitude faster for training and evaluation.
We can train fastText on more than one billion words in less than ten minutes using a standard multicore~CPU, and classify half a million sentences among~312K classes in less than a minute.
"""

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from colour import Color
import re
# %matplotlib inline

# %%
# Reading data from .csv file
dframe = pd.read_csv('productsfull.csv')
dframe.head()
# Out:
#                                            colorname  \
# 0                                                 []
# 1  ['Bright Sapphire', 'Cactus', 'Night', 'Teal S...
# 2                              ['Mossy Oak Country']
# 3                                            ['Owl']
# 4                                ['Dark Gray Multi']
#
#                                                desc2  \
# 0                                                 []
# 1                                                 []
# 2  ["Maine State Game Wardens are the pinnacle of...
# 3                                                 []
# 4                                                 []
#
#                                          description fit  \
# 0  ["The world's #1-selling hunting knife in its ...  []
# 1  ["We've combined the freedom of a sandal with ...  []
# 2  ["This is the ultimate sportsman's day pack. D...  []
# 3  ['These fur-ocious kids’ animal slippers will ...  []
# 4  ['Our Baby Bogs set the standard in toddlers’ ...  []
#
#                                            fitinfo  \
# 0                                               []
# 1                       ['Half sizes order down.']
# 2                                               []
# 3  ['Half sizes order up.', 'Sized for toddlers.']
# 4                                               []
#
#                                      fulldescription      itemid  \
# 0  ["The world's #1-selling hunting knife in its ...  ['219529']
# 1  ["We've combined the freedom of a sandal with ...  ['504069']
# 2  ["This is the ultimate sportsman's day pack. D...  ['505356']
# 3  ['These fur-ocious kids’ animal slippers will ...  ['219943']
# 4  ['Our Baby Bogs set the standard in toddlers’ ...  ['306187']
#
#                                       name  \
# 0          Buck 110 Folding Hunter's Knife
# 1                   Kids' Explorer Sandals
# 2            Maine Warden's Day Pack, Camo
# 3           Toddlers' Animal Paws Slippers
# 4  Toddlers' Baby Bogs Boots, Classic Dino
#
#                                                  url
# 0  https://www.llbean.com/llb/shop/38592?page=buc...
# 1  https://www.llbean.com/llb/shop/120346?page=ki...
# 2  https://www.llbean.com/llb/shop/121924?page=ma...
# 3  https://www.llbean.com/llb/shop/38106?page=tod...
# 4  https://www.llbean.com/llb/shop/118942?page=to...

# %%
# Dropping useless columns
df = dframe.drop(['desc2', 'fit', 'fitinfo', 'fulldescription', 'itemid', 'name', 'url'], axis=1)
df.head()
# Out:
#                                            colorname  \
# 0                                                 []
# 1  ['Bright Sapphire', 'Cactus', 'Night', 'Teal S...
# 2                              ['Mossy Oak Country']
# 3                                            ['Owl']
# 4                                ['Dark Gray Multi']
#
#                                          description
# 0  ["The world's #1-selling hunting knife in its ...
# 1  ["We've combined the freedom of a sandal with ...
# 2  ["This is the ultimate sportsman's day pack. D...
# 3  ['These fur-ocious kids’ animal slippers will ...
# 4  ['Our Baby Bogs set the standard in toddlers’ ...

# %%
# Function that checks if string is a color name or not
def check_color(col):
    try:
        if col == "":
            return False
        return Color(col)
    except ValueError:
        return False

# %%
# Getting color names of every single dataframe row
colnames = []
for i in range(df.shape[0]):
    tmp = re.findall(r'\w+', df.iloc[i][1].lower())
    colnames.append([])
    for j in tmp:
        if check_color(j):
            colnames[i].append(j)

# %%
colnames_from_df = df['colorname'].apply(lambda x: re.findall(r'\w+', x.lower()))

# %%
# Finding intersection between colorname column and our extracted color names from description column
compared = []
for i in range(len(colnames)):
    if not colnames[i]:
        continue
    intersect = set(colnames[i]).intersection(colnames_from_df[i])
    if intersect:
        compared.append((i, list(intersect)[0])) # adding row indexes

# %%
compared
# Out:
# [(172, 'red'),
#  (267, 'blue'),
#  (319, 'black'),
#  (624, 'red'),
#  (630, 'blue'),
#  (667, 'red'),
#  (723, 'orange'),
#  (733, 'orange'),
#  (736, 'orange'),
#  (748, 'orange'),
#  (763, 'snow'),
#  (781, 'snow'),
#  (1007, 'black'),
#  (1094, 'orange'),
#  (1162, 'black'),
#  (1254, 'red'),
#  (1290, 'snow'),
#  (1306, 'snow'),
#  (1331, 'orange'),
#  (1341, 'orange'),
#  (1355, 'orange'),
#  (1455, 'red'),
#  (1674, 'indigo'),
#  (1794, 'indigo'),
#  (1840, 'indigo'),
#  (1848, 'indigo'),
#  (1958, 'black'),
#  (2249, 'navy'),
#  (2569, 'black'),
#  (2783, 'red'),
#  (2871, 'orange'),
#  (3111, 'linen'),
#  (3212, 'white'),
#  (3216, 'blue'),
#  (3435, 'indigo'),
#  (3461, 'red'),
#  (3817, 'red'),
#  (3928, 'khaki'),
#  (3946, 'indigo'),
#  (4271, 'black'),
#  (4369, 'black'),
#  (4907, 'black'),
#  (5079, 'black'),
#  (5373, 'khaki'),
#  (5379, 'khaki'),
#  (5424, 'indigo'),
#  (5512, 'indigo'),
#  (6579, 'indigo'),
#  (6646, 'orange'),
#  (6892, 'khaki'),
#  (7435, 'khaki'),
#  (7498, 'khaki'),
#  (7516, 'khaki'),
#  (7571, 'khaki'),
#  (7586, 'red'),
#  (8499, 'navy'),
#  (8786, 'blue'),
#  (9194, 'black'),
#  (9209, 'black'),
#  (9476, 'navy'),
#  (9606, 'navy'),
#  (9659, 'khaki'),
#  (10318, 'khaki'),
#  (10319, 'khaki'),
#  (10323, 'khaki'),
#  (10329, 'khaki'),
#  (10331, 'khaki'),
#  (10336, 'khaki'),
#  (10337, 'khaki'),
#  (10382, 'indigo'),
#  (10591, 'khaki'),
#  (10676, 'orange'),
#  (10738, 'khaki'),
#  (10740, 'khaki'),
#  (10746, 'khaki'),
#  (10759, 'khaki'),
#  (10769, 'khaki'),
#  (10773, 'khaki'),
#  (11482, 'blue'),
#  (11525, 'orange'),
#  (11616, 'orange'),
#  (11746, 'indigo'),
#  (11976, 'khaki'),
#  (11983, 'khaki'),
#  (11986, 'khaki'),
#  (11992, 'khaki'),
#  (11999, 'khaki'),
#  (12003, 'khaki'),
#  (12006, 'khaki'),
#  (12070, 'orange'),
#  (12293, 'orange'),
#  (12500, 'orange'),
#  (12563, 'blue'),
#  (13121, 'blue'),
#  (14321, 'black'),
#  (14406, 'black'),
#  (14518, 'black'),
#  (14671, 'orange'),
#  (14724, 'black'),
#  (14741, 'orange'),
#  (14827, 'orange'),
#  (14873, 'snow'),
#  (14881, 'snow'),
#  (14954, 'orange'),
#  (15232, 'orange'),
#  (15810, 'orange'),
#  (15820, 'orange'),
#  (15861, 'orange'),
#  (15988, 'snow'),
#  (16030, 'orange'),
#  (16034, 'orange'),
#  (16038, 'orange'),
#  (16256, 'black'),
#  (16262, 'blue'),
#  (16544, 'snow'),
#  (16927, 'red'),
#  (16949, 'blue'),
#  (16976, 'blue'),
#  (17029, 'blue'),
#  (17033, 'black'),
#  (17046, 'red'),
#  (17200, 'blue'),
#  (17218, 'red'),
#  (17333, 'red'),
#  (17442, 'red'),
#  (17522, 'red'),
#  (17523, 'red'),
#  (17748, 'red'),
#  (17762, 'red'),
#  (17899, 'blue'),
#  (19141, 'blue'),
#  (19152, 'black'),
#  (19433, 'orange'),
#  (19654, 'orange'),
#  (19787, 'black'),
#  (20182, 'red'),
#  (20286, 'orange'),
#  (20569, 'orange'),
#  (20726, 'red'),
#  (20759, 'black'),
#  (20781, 'red'),
#  (21407, 'gray'),
#  (21633, 'black'),
#  (21893, 'black'),
#  (21911, 'khaki'),
#  (21917, 'khaki'),
#  (21921, 'khaki'),
#  (22148, 'indigo'),
#  (22152, 'indigo'),
#  (22238, 'white'),
#  (22350, 'navy'),
#  (22626, 'black'),
#  (22890, 'indigo'),
#  (22915, 'indigo'),
#  (23053, 'indigo'),
#  (23056, 'indigo'),
#  (23066, 'khaki'),
#  (23067, 'khaki'),
#  (23070, 'khaki'),
#  (23071, 'indigo'),
#  (23193, 'indigo'),
#  (23653, 'orange'),
#  (23961, 'indigo'),
#  (24106, 'red'),
#  (24116, 'red'),
#  (24264, 'red'),
#  (24325, 'red'),
#  (24661, 'white'),
#  (24673, 'white'),
#  (24686, 'gray'),
#  (24759, 'gray'),
#  (24782, 'gray'),
#  (25014, 'blue'),
#  (25038, 'linen'),
#  (25062, 'white'),
#  (25064, 'white')]

# %%
#!pip install fasttext

# %%
# Reading second .csv file

df_classified = pd.read_csv('productsclassified.csv')
df_classified.drop(['desc2', 'fit', 'fitinfo', 'fulldescription', 'itemid', 'name', 'url', 'colorname'], axis=1, inplace=True)

# %%
# Train-test splitting our data

from sklearn.model_selection import train_test_split
import csv

train, test = train_test_split(df_classified, test_size=0.2, shuffle=False)

# %%
train.head()
# Out:
#                                          description Classification
# 0  ['These waterproof hiking boots for men are ru...          Boots
# 1  ["The next level of weather protection. This l...        Jackets
# 2  ['Great grip and extra breathability make thes...          Shoes
# 3  ["This lightweight fly rod delivers outstandin...  Fishing Tools
# 4  ['Add a pop of paddling fun to your bed, chair...        Pillows

# %%
# Processing data to train our future model

labeled_data = "__label__"+train['Classification'].apply(lambda x: "".join(x.split())) + " " + train['description'].apply(lambda  x:x[2:-2])

# %%
# Converting labeled data into .txt file

labeled_data.to_csv('train.txt', index = False, sep = ' ', header = None, quoting=csv.QUOTE_NONE, quotechar="", escapechar = " ")

# %%
# Importing and training our model

import fasttext
model = fasttext.train_supervised(input='train.txt', epoch=2000, wordNgrams=2, lr=1)

# %%
# Predicting for a random description

model.predict('These  waterproof  hiking  boots  for  men  are  rugged  enough  for  peak  performance  yet  light  and  quick  enough  to  keep  feet  from  feeling  weighed  down.')
# Out:
# (('__label__Boots',), array([0.99993289]))

# %%
# Cleaning our test descriptions from useless symbols 

test['description'] = test['description'].apply(lambda x:x[2:-2])

# %%
# Making knows classes and predicted classes similar to compare

test['Classified'] = test['description'].apply(lambda x: model.predict(x)[0][0][9:])
test['Classification'] = test['Classification'].apply(lambda x: ''.join(x.split()))

# %%
test.head(18)
# Out:
#                                            description Classification  \
# 197  Our popular men's long-sleeve quarter-zip cycl...         Shirts
# 198  A technical ultralight pack, the Osprey Atmos ...           Bags
# 199  Perfectly cool and casual, this striped linen ...        Dresses
# 200  With their athletic profile and heavy-duty tre...          Shoes
# 201  Few things are as rewarding as trading in your...       Slippers
# 202  Field tested in a variety of situations, from ...   FishingTools
# 203  100% unshrinkable, and exclusively ours. This ...         Shirts
# 204  Now lighter, these are the perfect trail shoes...          Shoes
# 205  We've put a colorful spin on a perennial favor...          Boots
# 206  A lightweight three-season sleeping pad that o...   SleepingBags
# 207  The most convenient, supportive wading staff w...   FishingTools
# 208  The Nikon Monarch 5 binoculars provide superio...     Binoculars
# 209  Perfect for everything from a walk in the park...          Shoes
# 210  There's nothing like greeting the day in these...       Slippers
# 211  The improved Osprey Stratos hiking pack provid...           Bags
# 212  We chose softly textured slub cotton for this ...         Shirts
# 213  This ultra-comfortable universal liner is desi...     Baselayers
# 214  Lightweight protection in a classic colorblock...        Jackets
#
#        Classified
# 197        Shirts
# 198          Bags
# 199          Bags
# 200         Shoes
# 201         Pants
# 202  FishingTools
# 203        Shirts
# 204         Shoes
# 205       Jackets
# 206        Shorts
# 207        Shirts
# 208        Shirts
# 209         Shoes
# 210         Shoes
# 211         Boots
# 212         Pants
# 213          Bags
# 214       Jackets

# %%
# Counting model's accuracy

acc = sum(test['Classified']==test['Classification'])
print(f"Accuracy: {acc} / {test.shape[0]}")
# Out:
# Accuracy: 23 / 50

# %%
"""
You have successfully created an ML model that has a great performance. They have been using the model for 2 years.
Then suddenly the model performance drops. What could have possibly resulted in this outcome.
Could you have prevented it? If yes how. If not, what can you do now?
"""

"""
Model's degradation proccess is called Concept Drift. Main reason that could affect on our model performance over time is incomplete or old data.
Trends and world-wide events such as crisis, pandemic, etc, can impact our data, and there is no way to avoid them.
Solution could be refreshing our old data with new one and training a new model with it.
"""
